# %% [raw]
# ---
# title: Hospital Competition and the Provision of Community Benefits
# subtitle: How does hospital competition affect the provision of community benefits
# summary: I explore how hospital competition affect the provision level of community benefits by nonprofit hospitals in this article.
# authors:
# - admin
# tags:
# - hospital competition
# - Community Benefits
# categories: []
# date: "2021-02-05T00:00:00Z"
# lastMod: "2021-03-11T00:00:00Z"
# featured: false
# draft: false
#
# # Featured image
# # To use, add an image named `featured.jpg/png` to your page's folder.
# image:
#   caption: 'Image credit: [**Unsplash**](https://unsplash.com/photos/vGu08RYjO-s)'
#   focal_point: ""
#
# # Projects (optional).
# #   Associate this post with one or more of your projects.
# #   Simply enter your project's folder or file name without extension.
# #   E.g. `projects = ["internal-project"]` references
# #   `content/project/deep-learning/index.md`.
# #   Otherwise, set `projects = []`.
# projects: ["C:\Users\mehme\Documents\GitHub\personal_website\content\post\publication\conference-paper\index.md"]
# ---

# %%
from IPython.core.display import Image
Image('C:/Users/mehme/Documents/GitHub/personal_website/content/post/community_benefit/feature.jpg')

# %%
pip install -U academic
# Out:
# Collecting academicNote: you may need to restart the kernel to use updated packages.
# ERROR: Cannot uninstall 'ruamel-yaml'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.
#   Downloading academic-0.7.0-py3-none-any.whl (12 kB)
# Collecting ruamel.yaml==0.16.10
#   Downloading ruamel.yaml-0.16.10-py2.py3-none-any.whl (111 kB)
# Requirement already satisfied, skipping upgrade: requests in c:\users\mehme\anaconda3\lib\site-packages (from academic) (2.24.0)
# Requirement already satisfied, skipping upgrade: toml in c:\users\mehme\anaconda3\lib\site-packages (from academic) (0.10.1)
# Collecting bibtexparser==1.1.0
#   Downloading bibtexparser-1.1.0.tar.gz (46 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9"
#   Downloading ruamel.yaml.clib-0.2.2-cp38-cp38-win_amd64.whl (120 kB)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in c:\users\mehme\anaconda3\lib\site-packages (from requests->academic) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\mehme\anaconda3\lib\site-packages (from requests->academic) (2020.6.20)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\mehme\anaconda3\lib\site-packages (from requests->academic) (1.25.11)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in c:\users\mehme\anaconda3\lib\site-packages (from requests->academic) (2.10)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.0.3 in c:\users\mehme\anaconda3\lib\site-packages (from bibtexparser==1.1.0->academic) (2.4.7)
# Requirement already satisfied, skipping upgrade: future>=0.16.0 in c:\users\mehme\anaconda3\lib\site-packages (from bibtexparser==1.1.0->academic) (0.18.2)
# Building wheels for collected packages: bibtexparser
#   Building wheel for bibtexparser (setup.py): started
#   Building wheel for bibtexparser (setup.py): finished with status 'done'
#   Created wheel for bibtexparser: filename=bibtexparser-1.1.0-py3-none-any.whl size=37096 sha256=c75a7e35116deb4f97f0c1fca966ed89519edee50719322d3d62964b4a61f485
#   Stored in directory: c:\users\mehme\appdata\local\pip\cache\wheels\fe\c0\e7\199545741b30ceb5963fb879a05658c59aca36a44ed79a7eb5
# Successfully built bibtexparser
# Installing collected packages: ruamel.yaml.clib, ruamel.yaml, bibtexparser, academic
#   Attempting uninstall: ruamel.yaml
#     Found existing installation: ruamel-yaml 0.15.87
